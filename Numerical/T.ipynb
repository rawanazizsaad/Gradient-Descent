# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**3 + 3*x**2 + 3*x + 6


x = np.arange(-10, 10, 0.1)

y = f(x)


plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) = x^3 + 3x^2 + 3x + 6')
plt.grid(True)
plt.show()
